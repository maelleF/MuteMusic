# %%
import os
import numpy as np
import soundfile as sf
import librosa
import pandas

# %%
path = '/home/maellef/git/MuteMusic/data/StimuliFinal/long'
silences_nb = [3,4]
min=3
max=6

rng = np.random.default_rng(2022)

for category in os.listdir(path):
    for file in os.listdir(os.path.join(path, category)):
        name, ext = os.path.splitext(file)
        if ext == '.wav':
            path_wav=os.path.join(path, category, file)
            wav, sr = librosa.load(path_wav, sr=None)
            if len(wav)/sr > 65 or len(wav)/sr < 46:
                possible_nb_silences = [x for x in silences_nb if (len(wav)*0.25 >= x*min*sr) and (len(wav)*0.25 <= x*max*sr)]
                silence = rng.choice(possible_nb_silences)
                a = int(len(wav)*0.25)
                
                cond=True
                while cond:
                    test = [rng.choice(a) for _ in range(silence-1)]
                    test.append(0)
                    test.append(int(len(wav)*0.25))
                    test.sort()
                    durations=[]
                    for i in range(len(test)-1):
                        duration = test[i+1]-test[i]
                        if not (duration/sr > min and duration/sr < max):
                            break
                        else :
                            durations.append(duration/sr)
                            cond=False

                print(name, sr, len(wav)/sr, (len(wav)*0.25)/sr, possible_nb_silences, silence, durations)

# %%
wav, sr = librosa.load(path_wav, sr=None)

for dirpath, dirnames, files in os.walk(path):
    min_filename = ''
    wav_min = 3000000
    if len(files) > 0:
        for filename in files:
            name, ext = os.path.splitext(filename)
            if ext == '.wav':
                wav, wav_sr = librosa.load(os.path.join(dirpath, filename), sr=None)
                if len(wav) < wav_min:
                    wav_min = len(wav)
                    min_filename = filename
                if wav_sr != sr :
                    print(f'sr = {wav_sr} for {filename}')
                else :
                    pass
        print(f'check finished for {dirpath}, min duration is {wav_min/wav_sr}s for {min_filename}')

# %%
    while len(silences_length) 1= silence_nb:
        silences_lim = rng.choice(total_silence, size=silence_nb)
        silences_lim = np.concatenate((silences_lim, [0, total_silence]))
        silences_lim = np.sort(silences_lim)
        silences_length=[]
        for i in range(len(silences_lim)-1):
            duration = silences_lim[i+1]-silences_lim[i]
            if not (duration/sr > silence_min and duration/sr < silence_max):
                pass
            else :
                silences_length.append(duration)
    print(f'b{silences_length}')

# %%
#define the sizes and timestamps of all silences to be inserted into track (based on parameters)
def define_silences_timestamps(start_wav, end_wav, total_wav, sr,
                               percent_silence, silences_nb,
                               silence_min, silence_max, silence_interval_min):
    rng = np.random.default_rng(2023)
    total_silence = int(total_wav*percent_silence)
    possible_nb_silences = [x for x in silences_nb if (total_silence >= x*silence_min*sr) and (total_silence <= x*silence_max*sr)]
    silence_nb = int(rng.choice(possible_nb_silences))
    silences_length = [0]*silence_nb

    #--------------------------------------------------------------------------------------------------------
    while sum(silences_length) != total_silence:
        silences_length = rng.integers(low=silence_min*sr, high=silence_max*sr, size = silence_nb, endpoint=True)
    #-----------------------------------------------------------------------------------------------------------

    
    silences_timestamps=[]
    for silence_duration in silences_length:
        while True:
            start_silence = rng.integers(low=start_wav, high=end_wav-silence_duration, size = 1, endpoint=True)
            stop_silence = start_silence+silence_duration
            if len(silences_timestamps) > 0:
                correct_timestamp = []
                for (_, start, stop) in silences_timestamps: 
                    start_before_silence = stop_silence < (start - sr*silence_interval_min) 
                    start_after_silence = start_silence > (stop + sr*silence_interval_min)
                    correct_timestamp.append(start_before_silence + start_after_silence)
                    
                if np.prod(correct_timestamp):
                    silences_timestamps.append((silence_duration, start_silence[0], stop_silence[0]))
                    break
                else:
                    pass
            else:
                silences_timestamps.append((silence_duration, start_silence[0], stop_silence[0]))
                break
                
    #for silence_duration, start, stop in silences_timestamps:
        #print(silence_duration/sr, start/sr, stop/sr)
    
    return silences_timestamps

# %%
def insert_silences(wav, sr,
                    silences_timestamps,
                    fading_duration):
    #insert fading
    fadein = np.linspace(0,1,np.int32(fading_duration*sr))
    fadeout = np.linspace(1,0,np.int32(fading_duration*sr))
    wav[:np.int32(fading_duration*sr)] *= fadein
    wav[-np.int32(fading_duration*sr):] *= fadeout
    
    #insert silence in the track
    for (silence_duration, start, stop) in silences_timestamps:
        silence = np.zeros(np.int32(silence_duration))
        wav[start:stop] *= silence
    
    return wav

# %%
#define all parameters needed
path = '/home/maellef/git/MuteMusic/data/StimuliFinal/long'
outpath = "/home/maellef/git/MuteMusic/data/StimuliFinal/silenced"

EDA ?
during the instructions :
explicit ; please try not to nod your head/tap/
How well did you imagine  
not at all / I could imagine perfectly 

partially randomize order of tracks (5U/5F)

fading_duration = 1
intro_duration = 5
silence_min = 3
silence_max = 6
subset de 4/5/6 silences
silences_nb = [3,4]
silence_interval_min = 3/5

silences_df = pandas.DataFrame()

for category in os.listdir(path):
    for file in os.listdir(os.path.join(path, category)):
        name, ext = os.path.splitext(file)
        if ext == '.wav':
            path_wav=os.path.join(path, category, file)
            wav, sr = librosa.load(path_wav, sr=None)
            print(name, len(wav)/sr)
            silences_timestamps = define_silences_timestamps(start_wav = intro_duration*sr, end_wav=len(wav),
                                                             total_wav=len(wav), sr=sr,
                                                             percent_silence=0.25, silences_nb=silences_nb,
                                                             silence_min=silence_min, silence_max=silence_max, 
                                                             silence_interval_min=silence_interval_min)
            
            silenced_wav = insert_silences(wav, sr,silences_timestamps,fading_duration)
            print(silences_timestamps)
            if len(silences_timestamps) == 4:
                silence_data = pandas.DataFrame([{'category':category,
                                                  'track':file,
                                                  'S1_duration':silences_timestamps[0][0], 'S1_start':silences_timestamps[0][1], 'S1_stop':silences_timestamps[0][2],
                                                  'S2_duration':silences_timestamps[1][0], 'S2_start':silences_timestamps[1][1], 'S2_stop':silences_timestamps[1][2],
                                                  'S3_duration':silences_timestamps[2][0], 'S3_start':silences_timestamps[2][1], 'S3_stop':silences_timestamps[2][2],
                                                  'S4_duration':silences_timestamps[3][0], 'S4_start':silences_timestamps[3][1], 'S4_stop':silences_timestamps[3][2],
                                                 }])
            else:
                silence_data = pandas.DataFrame([{'category':category,
                                                  'track':file,
                                                  'S1_duration':silences_timestamps[0][0], 'S1_start':silences_timestamps[0][1], 'S1_stop':silences_timestamps[0][2],
                                                  'S2_duration':silences_timestamps[1][0], 'S2_start':silences_timestamps[1][1], 'S2_stop':silences_timestamps[1][2],
                                                  'S3_duration':silences_timestamps[2][0], 'S3_start':silences_timestamps[2][1], 'S3_stop':silences_timestamps[2][2],
                                                  }])
            silences_df = pandas.concat([silences_df, silence_data])
            

            new_name = f'{name}_silenced{ext}'
            new_path = os.path.join(outpath, category)
            os.makedirs(new_path, exist_ok=True)
            sf.write(file=os.path.join(new_path, new_name), data = silenced_wav, samplerate=sr)

output_file= os.path.join(outpath, 'silences_data.tsv')
silences_df.to_csv(output_file, sep='\t', index=False, header=True)
print(silences_df)
# Out:
# Super_Mario_Bros_(NES)_Music_Overworld_Theme 59.0
# [(213419, 2584295, 2797714), (282701, 1388472, 1671173), (211880, 563782, 775662)]
# Super_Mario_Bros_3_Boss_Battle 57.0
# [(268777, 574741, 843518), (151855, 2378924, 2530779), (263368, 1766302, 2029670)]
# Final_Fantasy_7_Music_Aeriths_Theme 57.0
# [(268777, 574741, 843518), (151855, 2378924, 2530779), (263368, 1766302, 2029670)]
# Super_Mario_Bros_(NES)_Music_Castle_Theme 47.0
# [(172647, 976473, 1149120), (236502, 1464734, 1701236), (154851, 536921, 691772)]
# Super_Mario_Bros_3_Castle_Theme 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Super_Mario_Bros_3_Athletic_Theme 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Super_Mario_Bros_(NES)_Music_Underground_Theme 49.0
# [(208228, 1516495, 1724723), (204508, 1954615, 2159123), (175264, 728879, 904143)]
# Megalovania_Undertale 56.0
# [(163768, 1019277, 1183045), (259524, 2005723, 2265247), (248708, 258506, 507214)]
# Sim_City_Growth_extended 48.92725
# [(186059, 1880006, 2066065), (177654, 973378, 1151032), (223414, 1457523, 1680937)]
# Super_Mario_Bros_3_Underwater_Theme 46.0
# [(164116, 397719, 561835), (214743, 1498801, 1713544), (173141, 1051444, 1224585)]
# Castlevania_4_Bloody_Tears_(Super_Nintendo) 58.0
# [(277779, 1554553, 1832332), (235786, 682024, 917810), (182435, 1129952, 1312387)]
# Streets_Of_Rage_1_OST_Stage_1 45.0
# [(172992, 696640, 869632), (203811, 1574541, 1778352), (163197, 1960672, 2123869)]
# Street_Fighter_II_Champion_Edition_Arcade_Music_Guile_Theme_(CPS_1) 55.0
# [(277702, 1985465, 2263167), (160537, 1480538, 1641075), (221761, 441187, 662948)]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1) 61.0
# [(250373, 2426501, 2676874), (241950, 1856556, 2098506), (239677, 1230955, 1470632)]
# Mortal_Kombat_(Sega_Genesis)_Opening_Theme 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# Celeste_Original_Soundtrack_03_Resurrections 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Invincibility_Sonic_the_Hedgehog_2 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# Aladdin_Genesis_Music_Ending 65.0
# [(287299, 1722528, 2009827), (212631, 599112, 811743), (280070, 958906, 1238976)]
# Donkey_Kong_Country_OST_(Super_Nintendo)_DK_Island_Swing 59.0
# [(213419, 2584295, 2797714), (282701, 1388472, 1671173), (211880, 563782, 775662)]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Shinobi_Walk_(level_4_2) 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# Sid_Meiers_Civilization_SNES_OST_06_City_Menu 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Super_Mario_Bros_3_Airship 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Japonesque_(level_1_1) 44.0
# [(150830, 786560, 937390), (196928, 1193967, 1390895), (180242, 1541922, 1722164)]
# Populous_(SNES_SFC)_BGM_01_Title_Theme 49.0
# [(208228, 1516495, 1724723), (204508, 1954615, 2159123), (175264, 728879, 904143)]
# Sonic_The_Hedgehog_OST_Green_Hill_Zone 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme 54.0
# [(239361, 1124838, 1364199), (185442, 554268, 739710), (223197, 1596577, 1819774)]
# Original_Tetris_theme_(Tetris_Soundtrack) 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Super_Mario_Bros_3_Overworld_1_Theme 54.0
# [(239361, 1124838, 1364199), (185442, 554268, 739710), (223197, 1596577, 1819774)]
# Space_Harrier_Music_MAIN_THEME 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# The_Imperial_March_(Darth_Vaders_Theme) 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# 2001_l_odyssée_de_l_espace 61.0
# [(250373, 2426501, 2676874), (241950, 1856556, 2098506), (239677, 1230955, 1470632)]
# Kikis_Delivery_Service 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# Main_Title_Terminator_2_Theme_(Remastered_2017) 54.0
# [(239361, 1124838, 1364199), (185442, 554268, 739710), (223197, 1596577, 1819774)]
# Yakety_Sax(1983_version) 45.0
# [(172992, 696640, 869632), (203811, 1574541, 1778352), (163197, 1960672, 2123869)]
# Star_Trek_the_Next_Generation_(Main_Title) 56.0
# [(163768, 1019277, 1183045), (259524, 2005723, 2265247), (248708, 258506, 507214)]
# The_4_Seasons_Op_8_4_RV_297_Winter 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Lux_Aeterna_from_Requiem_for_a_Dream 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Game_of_Thrones_Main_Title 56.0
# [(163768, 1019277, 1183045), (259524, 2005723, 2265247), (248708, 258506, 507214)]
# My_Name_is_Nobody_Good_Luck_Jack 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Hook_prologue 44.0
# [(150830, 786560, 937390), (196928, 1193967, 1390895), (180242, 1541922, 1722164)]
# il_porco_rosso 66.0
# [(280388, 1810885, 2091273), (272393, 411114, 683507), (239219, 2382284, 2621503)]
# Suite_bergamasque_CD_82_L_75_III_Clair_de_lune 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Dreaming_of_Bag_End 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# The_Pink_Panther_Theme 45.0
# [(172992, 696640, 869632), (203811, 1574541, 1778352), (163197, 1960672, 2123869)]
# Gnossienne_No1 63.0
# [(203979, 2537525, 2741504), (265359, 498652, 764011), (286662, 1301713, 1588375)]
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme) 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# Make_Em_Laugh 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Moonlight_Sonata 47.0
# [(172647, 976473, 1149120), (236502, 1464734, 1701236), (154851, 536921, 691772)]
# Body_and_soul 59.0
# [(213419, 2584295, 2797714), (282701, 1388472, 1671173), (211880, 563782, 775662)]
# Waltz_No_2 77.0
# [(251371, 1739807, 1991178), (149567, 912047, 1061614), (277124, 483757, 760881), (245938, 2808534, 3054472)]
# Another_Brick_In_The_Wall_(Part_1) 45.0
# [(172992, 696640, 869632), (203811, 1574541, 1778352), (163197, 1960672, 2123869)]
# The_Moldau 54.0
# [(239361, 1124838, 1364199), (185442, 554268, 739710), (223197, 1596577, 1819774)]
# Stairway_To_Heaven 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# The_Office_(Main_Theme) 62.0
# [(255279, 1436743, 1692022), (211036, 470801, 681837), (277685, 1975370, 2253055)]
# Back_To_The_Future 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# Babooshka 55.0
# [(277702, 1985465, 2263167), (160537, 1480538, 1641075), (221761, 441187, 662948)]
# Mrs_Robinson 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Mister_Sandman 46.0
# [(164116, 397719, 561835), (214743, 1498801, 1713544), (173141, 1051444, 1224585)]
# Take_Me_Home_Country_Roads 54.0
# [(239361, 1124838, 1364199), (185442, 554268, 739710), (223197, 1596577, 1819774)]
# No_Woman_No_Cry 64.0
# [(272412, 2148929, 2421341), (218204, 1069400, 1287604), (277384, 2729054, 3006438)]
# I_Will_Survive 68.0
# [(256063, 957336, 1213399), (277610, 2593985, 2871595), (282327, 1680927, 1963254)]
# Everybody_Wants_To_Rule_The_World 58.0
# [(277779, 1554553, 1832332), (235786, 682024, 917810), (182435, 1129952, 1312387)]
# Living_Together 71.0
# [(279558, 866478, 1146036), (287594, 1827985, 2115579), (284848, 2551696, 2836544)]
# Paperback_writer 46.0
# [(164116, 397719, 561835), (214743, 1498801, 1713544), (173141, 1051444, 1224585)]
# Never_Gonna_Give_You_Up 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# Synchronicity 47.0
# [(172647, 976473, 1149120), (236502, 1464734, 1701236), (154851, 536921, 691772)]
# Monday_Monday 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Highway_to_Hell 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Jailhouse_Rock 52.0
# [(229435, 1618289, 1847724), (199955, 2038675, 2238630), (194610, 605253, 799863)]
# I_Can't_Get_No_Satisfaction 67.0
# [(252487, 2138242, 2390729), (282436, 856232, 1138668), (269077, 1448213, 1717290)]
# Rain 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# Goodbye_Blue_Sky 48.0
# [(206174, 2092771, 2298945), (197518, 1574233, 1771751), (172308, 1219357, 1391665)]
# Cant_Live_With_You_Cant_Live_Without_You 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Murder_by_Numbers 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Why_You_Wanna_Trip_on_Me 53.0
# [(242421, 1126855, 1369276), (198139, 637440, 835579), (195440, 1917948, 2113388)]
# Its_Raining_Men 62.0
# [(255279, 1436743, 1692022), (211036, 470801, 681837), (277685, 1975370, 2253055)]
# Make_Em_Laugh 65.0
# [(287299, 1722528, 2009827), (212631, 599112, 811743), (280070, 958906, 1238976)]
# Creep 49.0
# [(208228, 1516495, 1724723), (204508, 1954615, 2159123), (175264, 728879, 904143)]
# Gangstas_Paradise 61.0
# [(250373, 2426501, 2676874), (241950, 1856556, 2098506), (239677, 1230955, 1470632)]
# Hotel_California 78.0
# [(263649, 1144505, 1408154), (209705, 3055851, 3265556), (231238, 2221345, 2452583), (231408, 1621757, 1853165)]
# Another_Brick_In_The_Wall_(Part_1) 60.0
# [(255697, 2556403, 2812100), (271748, 1740173, 2011921), (192555, 1018148, 1210703)]
# Material_Girl 50.0
# [(175110, 1574127, 1749237), (248471, 2072293, 2320764), (176419, 358670, 535089)]
# I_ll_Be_There_for_You 47.0
# [(172647, 976473, 1149120), (236502, 1464734, 1701236), (154851, 536921, 691772)]
#      category                                             track  S1_duration  \
# 0   Synthetic  Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav       213419
# 0   Synthetic                Super_Mario_Bros_3_Boss_Battle.wav       268777
# 0   Synthetic           Final_Fantasy_7_Music_Aeriths_Theme.wav       268777
# 0   Synthetic     Super_Mario_Bros_(NES)_Music_Castle_Theme.wav       172647
# 0   Synthetic               Super_Mario_Bros_3_Castle_Theme.wav       242421
# ..        ...                                               ...          ...
# 0      Lyrics                             Gangstas_Paradise.wav       250373
# 0      Lyrics                              Hotel_California.wav       263649
# 0      Lyrics            Another_Brick_In_The_Wall_(Part_1).wav       255697
# 0      Lyrics                                 Material_Girl.wav       175110
# 0      Lyrics                         I_ll_Be_There_for_You.wav       172647
#
#     S1_start  S1_stop  S2_duration  S2_start  S2_stop  S3_duration  S3_start  \
# 0    2584295  2797714       282701   1388472  1671173       211880    563782
# 0     574741   843518       151855   2378924  2530779       263368   1766302
# 0     574741   843518       151855   2378924  2530779       263368   1766302
# 0     976473  1149120       236502   1464734  1701236       154851    536921
# 0    1126855  1369276       198139    637440   835579       195440   1917948
# ..       ...      ...          ...       ...      ...          ...       ...
# 0    2426501  2676874       241950   1856556  2098506       239677   1230955
# 0    1144505  1408154       209705   3055851  3265556       231238   2221345
# 0    2556403  2812100       271748   1740173  2011921       192555   1018148
# 0    1574127  1749237       248471   2072293  2320764       176419    358670
# 0     976473  1149120       236502   1464734  1701236       154851    536921
#
#     S3_stop  S4_duration   S4_start    S4_stop
# 0    775662          NaN        NaN        NaN
# 0   2029670          NaN        NaN        NaN
# 0   2029670          NaN        NaN        NaN
# 0    691772          NaN        NaN        NaN
# 0   2113388          NaN        NaN        NaN
# ..      ...          ...        ...        ...
# 0   1470632          NaN        NaN        NaN
# 0   2452583     231408.0  1621757.0  1853165.0
# 0   1210703          NaN        NaN        NaN
# 0    535089          NaN        NaN        NaN
# 0    691772          NaN        NaN        NaN
#
# [85 rows x 14 columns]
